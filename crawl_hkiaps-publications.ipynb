# %% [markdown]
# This notebook crawls the publication from https://www.hkiaps.cuhk.edu.hk/hkiaps-publications-publication-list/

# %%
import csv
import time
from pathlib import Path
import httpx
from bs4 import BeautifulSoup


def scrape_publications(total_pages: int = 42) -> list[dict[str, str]]:
    """Scrape publication details including all metadata from all pages.

    Args:
        total_pages (int): Number of pages to scrape

    Returns:
        List[Dict[str, str]]: List of publication dictionaries with complete metadata

    """
    publications = []
    base_url = "https://www.hkiaps.cuhk.edu.hk/hkiaps-publications-publication-list/"

    for page in range(1, total_pages + 1):
        url = f"{base_url}?current_page={page}&filterCat[]=all&filterCat[]=asia-pacific-in-the-21st-century-book-series&filterCat[]=occasional-paper-series&filterCat[]=policy-research-report-series&filterCat[]=public-policy-forum-series&filterCat[]=research-monograph-series&filterCat[]=universities-service-centre-seminar-series&filterYear=all"
        print(f"Scraping page {page}/{total_pages}...")

        try:
            response = httpx.get(url, timeout=10, headers={"User-Agent": "Mozilla/5.0"})
            response.raise_for_status()
            soup = BeautifulSoup(response.content, "html.parser")
            containers = soup.find_all("div", class_="bg-fafafa")

            for container in containers:
                pub = {}
                headlines = container.find_all("div", class_="Headline3")
                if len(headlines) >= 2:
                    pub["id"] = headlines[0].get_text(strip=True)
                    pub["title"] = headlines[1].get_text(strip=True)
                buttons = container.find_all("a")
                for button in buttons:
                    href = button.get("href", "")
                    text = button.get_text(strip=True)
                    if "Abstract" in text:
                        pub["abstract_url"] = (
                            href
                            if href.startswith("http")
                            else f"https://www.hkiaps.cuhk.edu.hk{href}"
                        )
                    elif "Table of Contents" in text and href.endswith(".pdf"):
                        pub["toc_pdf"] = href
                    elif "PDF" in text and href.endswith(".pdf"):
                        pub["pdf_url"] = href
                info_div = container.find("div", class_="Body2")
                if info_div:
                    pub["metadata"] = info_div.get_text(separator="\n", strip=True)
                img = container.find("img", class_="publicationsImg")
                if img:
                    pub["image_url"] = img.get("src", "")
                publications.append(pub)
                print(f"  - {pub.get('id', 'N/A')}: {pub.get('title', 'N/A')[:50]}...")

            print(f"Found {len(containers)} publications on page {page}")
            time.sleep(5)

        except Exception as e:
            print(f"Error on page {page}: {e}")

    return publications


# Main execution
if __name__ == "__main__":
    print("Starting scraper...\n")
    publications = scrape_publications(total_pages=42) # Adjust total_pages as needed
# Out:
# Starting scraper...
#
# Scraping page 1/42...
#   - RM118: 潮汕人與一帶一路：金融教育領軍人...
#   - PRR09: 做強香港文化產業：軟實力的視角...
#   - PRR08: 做強香港家族辦公室業務：歷史、社會與文化的研究...
#   - RM117: 《潮領香江》...
#   - RM116: Building a Sustainable Healthcare System for Hong ...
#   - PRR07: Building a Sustainable Healthcare System for Hong ...
#   - RM115: 《潮汕人與一帶一路：商業貿易的開拓》...
#   - PRR06: 全球潮人與一帶一路學術政策國際論壇：論壇背景、紀要與政策建議...
#   - RM114: 《放寬香港視野：美國國家安全法研究》...
#   - PRR05: 香港青年社會流動研究：住戶統計調查的分析...
# Found 10 publications on page 1
# Scraping page 2/42...
#   - RM113: 《2020中國效應：台港民眾的態度變遷》...
#   - PRR04: 抗疫路上：香港市民眼中的新冠疫情衝擊與應變研究...
#   - RM112: 《勾勒與比較台港社會意索》...
#   - PRR03: 跨境就學就業的性別歧視及性騷擾問題...
#   - OP244(T): 被害者視角：刑法何以保護人工智能體？[繁體中文]...
#   - OP244(S): 被害者视角：刑法何以保护人工智能体？[简体中文]...
#   - PRR02: 顧己及人：推動正確行為以改善公廁衞生...
#   - OP243(T): 可否消滅貧窮？近二百年來貧窮面貌的變化[繁體中文]...
#   - OP243(S): 可否消灭贫穷？近二百年来贫穷面貌的变化[简体中文]...
#   - RM111: 《香港與台灣的社會政治新動向》...
# Found 10 publications on page 2
# Scraping page 3/42...
#   - OP242(T): 商談理性與刑事庭審實質化改革研究：基於刑法與刑事訴訟法交叉的視角[繁體中文]...
#   - OP242(S): 商谈理性与刑事庭审实质化改革研究：基于刑法与刑事诉讼法交叉的视角[简体中文]...
#   - PF20: 香港青年到內地發展的政策落差與優化...
#   - RM110: 《2015 香港區議會選舉：民意調查與分析》...
#   - PRR01: The Belt and Road Initiative and Global Competitiv...
#   - OP241: The Making of Ethnic Movements in Taiwan: Origins ...
#   - RM109: 《香港新青年》...
#   - OP240: 地方法院內部審判規則的治理：功能分析的視角...
#   - RM108: 《中國效應：台港民眾的觀感》...
#   - RM107: 《客家人 客家事》...
# Found 10 publications on page 3
# Scraping page 4/42...
#   - OP239: The Cultural Adaptation of Early Hong Kong Immigra...
#   - OP238: The Failure of Corporate Internal Controls and Int...
#   - OP237: 案件質量評估制度的功能研究...
#   - OP236: 香港人求診中醫的變化 (1993−2015)...
#   - RM106: 《香港特區二十年》...
#   - OP235: 香港青年與中國經驗...
#   - OP234: Regional Security in the Asia-Pacific and the Pivo...
#   - RM105: 《2012香港立法會選舉：民意調查與分析》...
#   - RM104: 《澳門對外關係：區域整合與交流》...
#   - OP233: Does Educational Expansion Increase Educational Ho...
# Found 10 publications on page 4
# Scraping page 5/42...
#   - RM103: 《台灣與香港的青年與社會變貌》...
#   - OP232: 香港專業移民在臺灣的政治態度...
#   - OP231: 女性身體與主體性：民元後的纏足與放足 (1911−1949)...
#   - RM102: 《2011 香港區議會選舉：民意調查與分析》...
#   - RM101: 《家在香港》...
#   - RM100: 《香港選舉資料匯編：2005－2012年》...
#   - RM099: 《吐露爭鳴：二零一四時事論叢》...
#   - OP230: Contentious Politics in Two Villages: Anti-High-Sp...
#   - RM098: 《一衣帶水：台港社會議題縱橫》...
#   - OP229: Comparing CEPA and ECFA: Economic Integration in t...
# Found 10 publications on page 5
# Scraping page 6/42...
#   - OP228: 口述史的性別維度：從工作與家庭對香港製衣業男、女工人的意義切入探討...
#   - RM097: 《構建澳門未來》...
#   - OP227: 從公民教育到國民教育的爭議...
#   - RM096: 《問鼎特首：民意調查與分析》...
#   - OP226: 「自由行」十年回顧：探討香港與內地的融合進程與嬗變...
#   - AP02: Health Systems: Challenges, Visions, and Reforms f...
#   - OP225: The Fall of Hong Kong Movies: A Post-mortem Invest...
#   - OP224: 香港全職人士的工作與家庭平衡...
#   - OP223: Gender Violence and the Media in Hong Kong...
#   - RM095: Women and Girls in Hong Kong Current Situations an...
# Found 10 publications on page 6
# Scraping page 7/42...
#   - OP222: Husband’s Resources, Power Motive, and Physical Vi...
#   - RM094: 《華人家族企業與股票市場》...
#   - OP221: From the EP-3 Incident to the USS Kitty Hawk–Song ...
#   - USC03: Strategies for Support of the Rural Elderly in Chi...
#   - RM093: 《從社經指標看香港社會變遷 》...
#   - OP220: What Makes Organizational Restructuring Stressful?...
#   - OP219: Guangzhou The Road to Regaining Its Central City S...
#   - RM092: 《華人傳播想像》...
#   - OP218: 香港與上海作為全球服務樞紐競爭或互補?...
#   - AP01: Hong Kong Divided?: Structures of Social Inequalit...
# Found 10 publications on page 7
# Scraping page 8/42...
#   - RM091: 《全球化與性別: 全球經濟重組對中國和東南亞女性的意義》...
#   - RM090: 《澳門特區新貌：十年發展與變化》...
#   - OP217: Shenzhen: 30 Years of Reform and Development and t...
#   - OP216: 香港市民置業態度及對政府房屋政策的評估...
#   - RM089: 《性通識：本性權利與道德爭議》...
#   - OP215: 當代監獄：美國與中國的跨文化比較...
#   - RM088: 《解讀臺港社會意向》...
#   - OP214: 不平等中的不平等：社會性別視角下的中國農民工...
#   - OP213: Shanghai: Urban Development and Regional Integrati...
#   - RM087: 《泛珠三角與香港：「十一五」下泛珠三角九省區和澳門與香港的發展》...
# Found 10 publications on page 8
# Scraping page 9/42...
#   - RM086: 《影視香港：身份認同的時代變奏》...
#   - OP212: 香港、天津兩地民眾對傳統與現代社會和諧觀的論述...
#   - RM085: 《限富扶貧：富裕中的貧乏（新編）》...
#   - OP211: Could the Soviet–Ukrainian and Lateran Models Work...
#   - PF19: 福利改革與社會企業：從制度理論解釋社會企業的發展...
#   - OP210: 「十一五」下泛珠三角與香港研究系列：X. 廣西與香港...
#   - RM084: 《為當下懷舊：文化保育的前世今生》...
#   - RM083: 《香港政治：發展歷程與核心課題》...
#   - OP209: Mass Movement and Interactive Political Process: L...
#   - RM082: 《開拓通識：知識份子的香港路》...
# Found 10 publications on page 9
# Scraping page 10/42...
#   - OP208: 「十一五」下泛珠三角與香港研究系列：IX. 雲南與香港...
#   - OP207: Rising Wages: Has China Lost Its Global Labor Adva...
#   - OP206: 香港的親職壓力、教養風格取向與家庭功能：現況、相互關係及啟示...
#   - RM081: Policies for the Sustainable Development of the Ho...
#   - OP205: 兒童視角下對於父母軀體虐待的認識：來自中國南京市的個案分析...
#   - OP204: 珠三角港台資的變遷及其對地方產業升級影響之比較研究：以東莞為例...
#   - RM080: 《城市文化與人文視野》...
#   - RM079: 《中國城市研究探索》...
#   - OP203: 「十一五」下泛珠三角與香港研究系列：VIII. 貴州與香港...
#   - OP202: 家庭友善政策與生育決定：香港的例子...
# Found 10 publications on page 10
# Scraping page 11/42...
#   - OP201: 政策表現與政府認受性：民意對香港政府的政策啟示...
#   - OP200: Who Would Change Their Vote and Why? A Case Study ...
#   - RM078: 《澳門社會新貌：成就與挑戰》...
#   - RM077: 《香港2007年區議會選舉投票行為》...
#   - RM076: 《互聯網在中國社會之崛起：四大城市的比較研究》...
#   - OP199: Strategic Responses to Political Changes：An Analys...
#   - OP198: 「十一五」下泛珠三角與香港研究系列：VII. 四川與香港...
#   - USC18: 第一次天安門事件再探：毛澤東時代末期的精英政治與危機應對...
#   - RM075: Indicators of Social Development: Hong Kong 2006...
#   - OP197: 2007年的中美經貿新矛盾：產品安全與保護主義...
# Found 10 publications on page 11
# Scraping page 12/42...
#   - RM074: 《新世紀臺港社會風貌》...
#   - OP196: 「十一五」下泛珠三角與香港研究系列：VI. 海南與香港...
#   - OP195: 「十一五」下泛珠三角與香港研究系列：V. 湖南與香港...
#   - PF18: 兒童信託基金：推行策略及各方的承擔...
#   - OP194: 「十一五」下泛珠三角與香港研究系列：IV. 福建與香港...
#   - RM073: 《從民意看香港的社會與政治》...
#   - OP193: 「十一五」下泛珠三角與香港研究系列：III. 澳門與香港...
#   - RM072: 《新世紀華人社會面貌：社會指標的分析》...
#   - OP192: 加強法定公營機構的認受性過程：比較市區重建局和土地發展公司...
#   - OP191: 地方財政如何支持廣東欠發達地區的經濟發展...
# Found 10 publications on page 12
# Scraping page 13/42...
#   - PF17: 香港華人家庭健康...
#   - OP190: 「十一五」下泛珠三角與香港研究系列：II. 廣東與香港...
#   - OP189: 香港華人家庭健康...
#   - OP188: 香港華人家庭健康和個人身心健康的關係...
#   - OP187: 「十一五」下泛珠三角與香港研究系列：I. 江西與香港...
#   - OP186: Taking Both Sides into Consideration: Ambivalence ...
#   - OP185: A Maidservant of the Revolution: He Xiangning and ...
#   - RM071: 《澳門社會實錄：從指標研究看生活素質》...
#   - RM070: 《網絡縱橫：泛珠三角區域基礎設施的發展》...
#   - OP184: Organizing for Sex Worker Rights in Hong Kong: The...
# Found 10 publications on page 13
# Scraping page 14/42...
#   - PF16: 香港公營廣播的未來走向...
#   - OP183: 香港公營廣播的未來走向...
#   - OP182: 香港的跨境「包二奶」現象與社會福利界的回應...
#   - OP181: 原居安老：理念、理論基礎與實務...
#   - OP180: 建設和諧社會的理論與實踐︰香港市民的觀點與相關政策啟示...
#   - OP179: US-Hong Kong Relations and the Response to Counter...
#   - RM069: The 2004 Legislative Council Elections in Hong Kon...
#   - OP178: Squaring the Welfare Circle in Post-1997 Hong Kong...
#   - OP177: Gender and Political Participation in Hong Kong: F...
#   - OP176: Policy Implications of Massively Multiplayer Onlin...
# Found 10 publications on page 14
# Scraping page 15/42...
#   - OP175: Taiwan: Sovereignty Reinterpreted: The Relations A...
#   - PF15: 如何促進香港社會和諧...
#   - OP174: 如何促進香港社會和諧...
#   - RM068: 《跨國網絡與華南僑鄉：文化、認同和社會變遷》...
#   - RM067: 《社會發展的趨勢與挑戰：香港與台灣的經驗》...
#   - PF14: 新高中通識敎育科與敎師專業發展...
#   - OP173: 新高中通識教育科與教師專業發展...
#   - OP172: Media Ideologies of Gender in Hong Kong...
#   - PF13: 政改的困局與出路...
#   - OP171: Primary Network Support and Emotional Distress in ...
# Found 10 publications on page 15
# Scraping page 16/42...
#   - OP170: 政改的困局與出路...
#   - OP169: Social Welfare and Women: The Dominant Approach an...
#   - RM066: 《港澳與珠三角西部發展：掌握發展新機遇》...
#   - PF12: 港深合作發展：尋求前瞻性的思維...
#   - OP168: The Equal Opportunities Commission and the Women's...
#   - OP167: 泛珠三角基礎建設發展研究系列：V. 電力...
#   - OP166: 港深合作發展：尋求前瞻性的思維...
#   - OP165: 「本土—全球化」現象：文化邊緣地區創意工業之境遇...
#   - OP164: 「中國重要的經濟中心」應成為北京城市性質的要件...
#   - OP163: 泛珠三角基礎建設發展研究系列：IV. 機場和民航...
# Found 10 publications on page 16
# Scraping page 17/42...
#   - RM065: Indicators of Social Development: Hong Kong 2004...
#   - RM064: 《香港選舉資料匯編: 2001年—2004年》...
#   - PF11: 如何制定減少跨代貧窮的社會政策...
#   - OP162: A Stranger in the House: Foreign Domestic Helpers ...
#   - OP161: 如何制定減少跨代貧窮的社會政策...
#   - OP160: 淺談香港新界后海灣淡水魚養殖業的歷史及其社區發展...
#   - OP159: Mobilization and Protest Participation in Post-han...
#   - RM063: 《泛珠三角與香港互動發展》...
#   - OP158: 泛珠三角基礎建設發展研究系列：III. 港口及航道...
#   - OP157: Noises and Interruptions: The Road to Democracy in...
# Found 10 publications on page 17
# Scraping page 18/42...
#   - OP156: Social Conflicts in Hong Kong: 1996-2002...
#   - RM062: The Western Pearl River Delta: Growth and Opportun...
#   - OP155: 泛珠三角基礎建設發展研究系列：II. 鐵路...
#   - OP154: Family Changes and Income Inequality under Globali...
#   - OP153: 泛珠三角基礎建設發展研究系列：I. 高速公路...
#   - OP152: Gender Differences in the Career Development of Pr...
#   - PF10: 分隔家庭對性別關係的衝擊...
#   - OP151: 分隔家庭對性別關係的衝擊...
#   - USC17: 身分和差異：1949-1965年中國社會的政治分層...
#   - OP150: "The Generation Gap" and Its Implications: Young E...
# Found 10 publications on page 18
# Scraping page 19/42...
#   - OP149: 香港與珠三角西部：從跨界角度看協作發展...
#   - RM061: 《香港、台灣和中國內地的社會階級變遷》...
#   - OP148: Enhancing the Livability of Asian Mega-cities...
#   - OP147: Fundraising for Charity on the Streets of Hong Kon...
#   - OP146: Space, Scale and the State: Reorganizing Urban Spa...
#   - OP145: Development and Transformation of the Free Port of...
#   - RM060: 《香港社會政治的延續與變遷》...
#   - OP144: Global City, Dual City?: Globalization and Social ...
#   - OP143: 華人個性的性別差異：香港與內地的比較...
#   - OP142: 台灣國族認同的再檢驗：R與Q的對話...
# Found 10 publications on page 19
# Scraping page 20/42...
#   - RM059: 《香港公營房屋五十年：金禧回顧與前瞻》...
#   - RM058: Fifty Years of Public Housing in Hong Kong: A Gold...
#   - OP141: 重建本土性別政治：香港處理虐妻法律的後殖民論述...
#   - RM057: Housing in Hong Kong: A Golden Jubilee Bibliograph...
#   - OP140: 主要官員問責制的成效及其對香港政治發展的影響...
#   - OP139: An Inquiry into the Relationship between Hong Kong...
#   - OP138: 經濟困難下香港市民的家庭生活狀況及人生態度：社會工作介入的啟示...
#   - OP137: The Management of Cultural Heritage in Hong Kong...
#   - RM056: Indicators of Social Development: Hong Kong 2001...
#   - PF09: 家庭在經濟不景時期的抗逆能力...
# Found 10 publications on page 20
# Scraping page 21/42...
#   - OP136: 家庭在經濟不景時期的抗逆能力...
#   - PF08: 內地與香港更緊密的經貿關係安排...
#   - OP135: 內地與香港更緊密的經貿關係安排...
#   - PF07: 從穩定樓市措施看房屋政策的銳變...
#   - OP134: 從穩定樓市措施看房屋政策的銳變...
#   - OP133: 經濟困難下香港市民的工作狀況與生活感受：弱勢社群的困境...
#   - OP132: 香港市民對新房屋政策的態度：社會階層矛盾的轉移...
#   - OP131: 二零零零年立法會選舉中的策略投票：一項實證研究...
#   - OP130: 離婚家庭中非與孩子同住的父╱母之親職參與...
#   - OP129: Internal and International Migration in China unde...
# Found 10 publications on page 21
# Scraping page 22/42...
#   - OP128: Observations on the Antiquities Trade in China: A ...
#   - OP127: 當代香港小說的文學社會學分析：文學、輩代與社會...
#   - OP126: 香港市民往中國內地居住、工作及置業的意欲：內地與香港整合的影響...
#   - OP125: 回歸後香港青少年的公民意識及公民教育態度：延續與變化...
#   - OP124: 特區政府醫療政策的評估：香港市民的觀點...
#   - OP123: 當代華人城市的民間社會組織：台北、香港、廣州、廈門的比較分析...
#   - OP122: Free Trade Zones in China: Review and Prospect...
#   - OP121: 台灣第五屆立法院選舉結果對其內部政局及兩岸關係的影響...
#   - OP120: 特區政府教育政策的評估：香港市民的觀點...
#   - OP119: 從美國調整台海政策看中美台三角關係的前景...
# Found 10 publications on page 22
# Scraping page 23/42...
#   - RM055: 《新經濟與中國西部開發》...
#   - RM054: 《社會轉型與文化變貌：華人社會的比較》...
#   - OP118: 特區政府社會福利政策的評估：香港市民的觀點...
#   - RM053: Indicators of Social Development: Hong Kong 1999...
#   - OP117: 特區政府房屋政策評估：香港市民的觀點...
#   - OP116: The Rise and Changing Nature of Taiwanese National...
#   - RM052: 《香港選舉資料匯編：1996年-2000年》...
#   - OP115: Growth without Catching Up: Organizational Dynamic...
#   - RM051: 《雲南省與湄公河區域合作：中國地方自主性的發展》...
#   - OP114: 香港與亞太區域發展：民意的探討...
# Found 10 publications on page 23
# Scraping page 24/42...
#   - OP113: Regional Polarization in Guangdong Province in Sou...
#   - USC16: 以農民合作的名義：1986-1999四川省農村合作基金會存亡里程...
#   - OP112: 民進黨大陸政策演變的政治經濟分析...
#   - USC15: 中蘇同盟的經濟背景：1948-1953...
#   - OP111: Education and Principle-based Opinion: A Study of ...
#   - OP110: 香港的「一國兩制」實踐：發展與挑戰...
#   - RM050: 《市場、階級與政治：變遷中的華人社會》...
#   - OP109: Globalization and the New Urban Challenge...
#   - OP108: Re-visiting Hong Kong Paradise: A Study of Japanes...
#   - OP107: The Occupational Attainments of the Five Major Dia...
# Found 10 publications on page 24
# Scraping page 25/42...
#   - OP106: 「一九七二架構」的鬆動解體與北京的對策...
#   - PF06: 污水排放策略：我們的冀求與承擔...
#   - OP105: 污水排放策略：我們的冀求與承擔...
#   - OP104: Earnings Divergence of Immigrants...
#   - OP103: Globalization and Regional Transformation in Pacif...
#   - OP102: Shanghai and Hong Kong as Service Hubs...
#   - RM049: 《福建暨閩南研究文獻選輯》...
#   - RM048: Press and Politics in Hong Kong: Case Studies from...
#   - PF05: 香港特區教育的再發展：論董特首的第二份施政報告...
#   - OP101: 香港特區教育的再發展：論董特首的第二份施政報告...
# Found 10 publications on page 25
# Scraping page 26/42...
#   - OP100: Health Care Reform in Hong Kong: A Discussion of t...
#   - OP099: Private Practice and Gendered Power: Women Doctors...
#   - PF04: 香港工業發展之前景...
#   - OP098: 香港工業發展之前景...
#   - RM047: 《邁向廿一世紀的中國：城鄉與區域發展》...
#   - RM046: 《邁向廿一世紀的中國：環境、資源與可持續發展》...
#   - RM045: 《邁向廿一世紀的中國：地理學的理論與方法》...
#   - OP097: Reconstructing the Democratic Discourses in Taiwan...
#   - OP096: Social Mobilization amidst Social Political Turbul...
#   - PF03: 亞洲金融危機一週年：堅守聯繫匯率的利弊...
# Found 10 publications on page 26
# Scraping page 27/42...
#   - OP095: 亞洲金融危機一週年：堅守聯繫匯率的利弊...
#   - RM044: Hong Kong Politics: A Bibliography...
#   - OP094: A Collision of Discourses: Japanese and Hong Kong ...
#   - OP093: Advertising Modernity: "Home," Space and Privacy...
#   - USC14: Distortions in the Opening: "Segmented Deregulatio...
#   - RM043: Indicators of Social Development: Hong Kong 1997...
#   - OP092: The Political Economy of Taiwan's Foreign Policy...
#   - PF02: 失業、貧窮與政府的承擔...
#   - OP091: 失業、貧窮與政府的承擔...
#   - OP090: 從世界秩序伸展看珠江口超巨都會崛起...
# Found 10 publications on page 27
# Scraping page 28/42...
#   - OP089: The Asian Financial Crisis and After: Problems and...
#   - OP088: 〈香港老年社會服務法案〉：一個建議成立的老年社會服務網絡...
#   - RM042: 《華人社會的變貌：社會指標的分析 》...
#   - RM041: A Bibliography of Gender Studies in Hong Kong: 199...
#   - RM040: On the South China Track: Perspectives on Anthropo...
#   - OP087: The Role of Medical Social Workers and their Relat...
#   - OP086: 香港社會福利狀況評估：自求多福心態面臨挑戰...
#   - RM039: 《中國律師反傾銷代理業務 》...
#   - RM038: Urban Development in Asia: Retrospect and Prospect...
#   - PF01: 安居樂業展明天：尋求公營與私營房屋進一步合作...
# Found 10 publications on page 28
# Scraping page 29/42...
#   - OP085: 安居樂業展明天：尋求公營與私營房屋進一步合作...
#   - OP084: Social Transformation, Nascent Civil Society and t...
#   - OP083: 香港特區政府的房屋政策：民意的趨向...
#   - OP082: A Critique of Theories of Urban Planning in China...
#   - OP081: Rethinking the Hong Kong Cultural Identity: The Ca...
#   - OP080: From the "Through Train" to "Setting Up the New St...
#   - OP079: The Myth of Hong Kong's Laissez-faire Economic Gov...
#   - OP078: 回歸後的香港青少年公民意識...
#   - OP077: Colonial Governance and the Hong Kong Story...
#   - OP076: Velvet Colonialism's Legacy to Hong Kong: 1967 and...
# Found 10 publications on page 29
# Scraping page 30/42...
#   - OP075: 機遇與選擇：擴大遼寧與香港經貿合作的思路與建議...
#   - OP074: Intergenerational Mobility in a Context of Socio-i...
#   - USC13: 江浙鄉鎮企業轉制案例研究...
#   - OP073: 香港社會福利狀況：一個公眾的評估...
#   - OP072: Democratization, Poverty of Political Leaders, and...
#   - OP071: The Pearl River Delta Urban System Plan: An Analys...
#   - OP070: 近年香港社會福利政策的發展：以彭定康的施政為案例...
#   - OP069: The Poverty of Political Education in Hong Kong Se...
#   - RM037: 《香港回歸與港臺關係》...
#   - OP068: 河南與香港的聯繫合作：現狀及前瞻...
# Found 10 publications on page 30
# Scraping page 31/42...
#   - OP067: Policy Implementation in Reform China: The Case of...
#   - RM036: Emerging Pluralism in Asia and the Pacific...
#   - OP066: Educating for Change: Development of Women's/Gende...
#   - OP065: Hongkongese or Chinese: The Problem of Identity on...
#   - RM035: 《中國軟件版權訴訟實務》...
#   - OP064: Political Attitudes in a Changing Context: The Cas...
#   - OP063: 公民意識與民族認同：後過渡期香港人的經驗...
#   - RM034: 《閩東南地區經濟和人口空間集聚與擴散研究》...
#   - RM033: Indicators of Social Development: Hong Kong 1995...
#   - OP062: Social Conflicts in Hong Kong: 1987-1995...
# Found 10 publications on page 31
# Scraping page 32/42...
#   - OP061: Withering Away of the Hong Kong Dream?: Women Work...
#   - OP060: Five Decades of Urbanization in Southeast Asia: A ...
#   - USC12: In Search of a Right Place? Chinese Nationalism in...
#   - OP059: The Colonial State and Rural Protests in Hong Kong...
#   - OP058: 中國經濟改革中的國營企業女工：管理控制與企業依賴的轉化...
#   - OP057: 香港青少年公民意識1996...
#   - RM032: The 1995 Legislative Council Elections in Hong Kon...
#   - OP056: World City Futures: The Role of Urban and Regional...
#   - OP055: 亞太轉型、區域成長圈與永續發展...
#   - USC11: Family Support Networks in the Chinese Countryside...
# Found 10 publications on page 32
# Scraping page 33/42...
#   - RM031: 《兩岸關係的矛盾與出路》...
#   - RM030: China's Regional Economic Development...
#   - OP054: Education Vouchers and Education Subsidy in Hong K...
#   - OP053: Housing the Masses in Asia: Two Decades After Habi...
#   - OP052: Hong Kong in Reenchantment: A Case Study of the Ne...
#   - OP051: The Road to the Development of Social Welfare in H...
#   - RM029: 《香港選舉資料匯編：1995年》...
#   - RM028: 《兩岸四地的互動整合：機遇與障礙》...
#   - RM027: 《華人社會社會指標研究新領域》...
#   - RM026: Global Change and the Commonwealth...
# Found 10 publications on page 33
# Scraping page 34/42...
#   - OP050: 香港人的族群認同與民族認同：一個自由主義的解釋...
#   - OP049: 選舉行為與意識的性別差異：以沙田區青少年為例...
#   - RM025: Hong Kong Journalists in Transition...
#   - OP048: 後過渡期香港青少年公民意識：全港與沙田的比較...
#   - USC10: From Leninist Discipline to Socialist Legalism: Pe...
#   - RM024: Indicators of Social Development: Hong Kong 1993...
#   - OP047: Indigenization of Social Science Methodology in Ho...
#   - RM023: Gender and Society in Hong Kong: A Statistical Pro...
#   - OP046: 政綱與選舉：一九九四年香港區議會選舉的迴歸分析...
#   - RM022: 《中國大陸婦女文獻目錄：1949-1994》...
# Found 10 publications on page 34
# Scraping page 35/42...
#   - RM021: 《兩岸經貿互動的隱憂與生機》...
#   - OP045: Intergenerational Social Mobility in Hong Kong: A ...
#   - OP044: The Ambivalence of Local Level Political Elites: V...
#   - RM020: Productivity, Efficiency and Reform in China's Eco...
#   - OP043: Urbanisation in China's Fujian Province Since 1978...
#   - OP042: Development Corridor in Fujian: Fuzhou to Zhangzho...
#   - OP041: Informal Mechanisms in Japanese Politics...
#   - RM019: 《香港選舉資料匯編：1982年-1994年》...
#   - RM018: Inequalities and Development: Social Stratificatio...
#   - RM017: 《發展與不平等：大陸與台灣之社會階層與流動》...
# Found 10 publications on page 35
# Scraping page 36/42...
#   - OP040: The Politics of Laissez-faire: Hong Kong's Strateg...
#   - OP039: 民主化與分離主義：台灣近年的政治發展與兩岸關係...
#   - OP038: Chinese Entrepreneurship in Context...
#   - OP037: Taiwan-Mainland Economic Nexus: Socio-Political Or...
#   - OP036: Planning the Future of the Asian City: A Twenty-fi...
#   - OP035: China's Regional Economic Development and Its Poli...
#   - OP034: Urban Research in Asia: Problems, Priorities, and ...
#   - USC09: The 1989 Democracy Movement in China: A Preliminar...
#   - OP033: Urban Research in Developing Countries: Towards an...
#   - OP032: Power and Dignity: Sexual Harassment on Campus in ...
# Found 10 publications on page 36
# Scraping page 37/42...
#   - OP031: Are Immigrants Assimilating Better Now than A Deca...
#   - OP030: Morality, Class and the Hong Kong Way of Life...
#   - OP029: Predicting Adolescent Deviant Behavior in Hong Kon...
#   - RM016: The New International Order in East Asia...
#   - OP028: The Birth and Growth of Academic Sociology in Hong...
#   - OP027: Social Work and Social Change: A Profile of the Ac...
#   - OP026: A Critical Review of the English Literature on Chi...
#   - OP025: The World Outside When the War Broke Out: A Compar...
#   - OP024: Elite-Mass Relationship in Hong Kong: A Look into ...
#   - RM015: Hong Kong Tried Democracy: The 1991 Elections in H...
# Found 10 publications on page 37
# Scraping page 38/42...
#   - OP023: Educational and Early Socioeconomic Status Attainm...
#   - OP022: Urban and Regional Development in China: Recent Tr...
#   - OP021: Labour under Industrial Restructuring in Hong Kong...
#   - OP020: Pre-Departure Concerns of Prospective Migrants fro...
#   - OP019: China: Urban Development towards the Year 2000...
#   - RM014: 《中國城市與區域發展：展望廿一世紀》...
#   - OP018: 香港小學課本裏的性別角色研究...
#   - RM013: Indicators of Social Development: Hong Kong 1990...
#   - RM012: Politics of Economic Cooperation in the Asia-Pacif...
#   - OP017: The Class Structure in Hong Kong...
# Found 10 publications on page 38
# Scraping page 39/42...
#   - USC08: Popular Protest in the 1989 Democracy Movement: Th...
#   - USC07: China's War on Poverty: A Case Study of Fujian Pro...
#   - OP016: The Reign of the Market: Economy and Industrial Co...
#   - OP015: Women's Concern Groups in Hong Kong...
#   - USC06: Conflict over Cabbages: The Reform of Wholesale Ma...
#   - OP014: 社會史與中國婦女研究...
#   - OP013: Non-institutional Economic Integration via Cultura...
#   - RM011: A Bibliography of Asia-Pacific Studies, Vol. III: ...
#   - RM010: A Bibliography of Asia-Pacific Studies, Vol. II: C...
#   - RM009: A Bibliography of Asia-Pacific Studies, Vol. I: As...
# Found 10 publications on page 39
# Scraping page 40/42...
#   - USC05: From Arranged Marriages to Love Matches in Urban C...
#   - USC04: New Nationalist Identities in Post-Leninist Transf...
#   - OP012: Economic Development of the Four Little Dragons: L...
#   - USC02: Rural China, 1985-1990: Are the Reforms Really Bog...
#   - OP011: Public Attitude toward Political Parties in Hong K...
#   - USC01: China's Transients and the State: A Form of Civil ...
#   - RM008: 《華人社會社會指標研究的發展》...
#   - OP010: From One Brand of Politics to One Brand of Politic...
#   - RM007: The Economics of Industrial Development in the Peo...
#   - OP009: A Proposal for Deposit Insurance in Hong Kong...
# Found 10 publications on page 40
# Scraping page 41/42...
#   - OP008: International Labour Migration: The Case of Hong K...
#   - OP007: The Urban Poor and Urban Basic Infrastructure Serv...
#   - RM006: Japan's Comprehensive National Security Strategy a...
#   - OP006: Retirement Benefit Programs: Analysis and a Propos...
#   - OP005: Explaining China's Export Drive: The Only Success ...
#   - OP004: Japan's Cultural Diplomacy and Cultivation of ASEA...
#   - OP003: Social Conflicts in Hong Kong, 1975-1986: Trends a...
#   - RM005: A Bibliography of Gender Studies in Hong Kong (199...
#   - RM004: 《中國家庭及其變遷》...
#   - RM003: 《華人社會之性別研究：研討會文選》...
# Found 10 publications on page 41
# Scraping page 42/42...
#   - RM002: Indicators of Social Development: Hong Kong 1988...
#   - RM001: 《兩岸經濟發展與亞太區域互動》...
#   - OP002: Bureaucratic Response to Political Change: Theoret...
#   - OP001: Decolonization Without Independence and the Povert...
# Found 4 publications on page 42
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 122
#     120 print("Starting scraper...\n")
#     121 publications = scrape_publications(total_pages=42) # Adjust total_pages as needed
# --> 122 save_to_csv(publications, dir_name="hkiaps-publications")
#     123 print("\n=== Summary ===")
#     124 print(f"Total publications: {len(publications)}")
#
# Cell In[1], line 94, in save_to_csv(publications, dir_name, filename)
#      84     return
#      85 fieldnames = [
#      86     "id",
#      87     "title",
#    (...)     92     "image_url",
#      93 ]
# ---> 94 with open(Path(dir_name) / filename, "w", newline="", encoding="utf-8") as f:
#      95     writer = csv.DictWriter(f, fieldnames=fieldnames, extrasaction="ignore")
#      96     writer.writeheader()
#
# File ~/git/hkiaps_cuhk/.venv/lib/python3.13/site-packages/IPython/core/interactiveshell.py:343, in _modified_open(file, *args, **kwargs)
#     336 if file in {0, 1, 2}:
#     337     raise ValueError(
#     338         f"IPython won't let you open fd={file} by default "
#     339         "as it is likely to crash IPython. If you know what you are doing, "
#     340         "you can use builtins' open."
#     341     )
# --> 343 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'hkiaps-publications/hkiaps_publications.csv'

# %%
def save_to_csv(
    publications: list[dict[str, str]], dir_name: str, filename: str = "hkiaps_publications.csv"
) -> None:
    """Save publications to CSV file.

    Args:
        publications (List[Dict[str, str]]): List of publication dictionaries
        filename (str): Output CSV filename

    Returns:
        None: Writes data to CSV file

    """
    if not publications:
        print("No publications to save")
        return
    fieldnames = [
        "id",
        "title",
        "metadata",
        "pdf_url",
        "toc_pdf",
        "abstract_url",
        "image_url",
    ]
    filepath = Path(dir_name) / filename
    filepath.parent.mkdir(parents=True, exist_ok=True)
    with Path(filepath).open("w", newline="", encoding="utf-8") as f:
        writer = csv.DictWriter(f, fieldnames=fieldnames, extrasaction="ignore")
        writer.writeheader()
        writer.writerows(publications)
    print(f"\nSaved {len(publications)} publications to {filename}")


save_to_csv(publications, dir_name="hkiaps-publications")
print("\n=== Summary ===")
print(f"Total publications: {len(publications)}")
# Out:
# Saved 414 publications to hkiaps_publications.csv
#
# === Summary ===
# Total publications: 414
