# %%
import csv
import time
from pathlib import Path

import httpx
from bs4 import BeautifulSoup

avaliable_year = [
    1982,
    1981,
    1980,
    1979,
    1978,
    1977,
    1976,
    1975,
    1974,
    1973,
    1972,
    1971,
]


def scrape_publications(year_list: list[int]) -> list[dict[str, str]]:
    """Scrape publication details including all metadata from all pages.

    Args:
        year_list (list[int]): List of years to crawl

    Returns:
        List[Dict[str, str]]: List of publication dictionaries with complete metadata

    """
    publications = []
    base_url = (
        "https://www.hkiaps.cuhk.edu.hk/src-publications/?current_page=1&filterYear="
    )

    for item in year_list:
        url = f"{base_url}{item}"
        print(f"Scraping publications for year: {item}")
        try:
            response = httpx.get(url, timeout=10, headers={"User-Agent": "Mozilla/5.0"})
            response.raise_for_status()
            soup = BeautifulSoup(response.content, "html.parser")
            containers = soup.find_all("div", class_="bg-fafafa")

            for container in containers:
                pub = {}
                headlines = container.find_all("div", class_="Headline3")
                if len(headlines) >= 2:
                    pub["id"] = headlines[0].get_text(strip=True)
                    pub["title"] = headlines[1].get_text(strip=True)
                buttons = container.find_all("a")
                for button in buttons:
                    href = button.get("href", "")
                    text = button.get_text(strip=True)
                    if "Abstract" in text:
                        pub["abstract_url"] = (
                            href
                            if href.startswith("http")
                            else f"https://www.hkiaps.cuhk.edu.hk{href}"
                        )
                    elif "Table of Contents" in text and href.endswith(".pdf"):
                        pub["toc_pdf"] = href
                    elif "PDF" in text and href.endswith(".pdf"):
                        pub["pdf_url"] = href
                info_div = container.find("div", class_="Body2")
                if info_div:
                    pub["metadata"] = info_div.get_text(separator=" ", strip=True)
                img = container.find("img", class_="publicationsImg")
                if img:
                    pub["image_url"] = img.get("src", "")
                publications.append(pub)
                print(f"  - {pub.get('id', 'N/A')}: {pub.get('title', 'N/A')[:50]}...")

            print(f"Found {len(containers)} publications on year {item}.\n")
            time.sleep(5)

        except Exception as e:
            print(f"Error on year {item}: {e}")

    return publications


# Main execution
if __name__ == "__main__":
    print("Starting scraper...\n")
    publications = scrape_publications(avaliable_year)  # Adjust total_pages as needed
# Out:
# Starting scraper...
#
# Scraping publications for year: 1982
#   - OP98: Social Change, Bureaucratic Rule, and Emergent Pol...
# Found 1 publications on year 1982.
#
# Scraping publications for year: 1981
#   - OP97: Local Administrative Reform in Hong Kong: Promises...
#   - OP96: The Impact of Interviewer Language and Ethnicity o...
#   - OP95: Aggressive Behavior in Chinese Society: The Proble...
# Found 3 publications on year 1981.
#
# Scraping publications for year: 1980
#   - OP94: A Pilot Study on the Victims of Motor-cycle Accide...
#   - OP93: The Government, Intermediate Organizations and Gra...
#   - OP92: Evaluating the Effectiveness of the Activity Appro...
#   - OP91: An Analysis of the Relationship between Language A...
#   - OP90: Development, Colonial Rule, and Intergroup Politic...
#   - OP89: Social Accommodation of Politics: The Case of the ...
#   - OP88: Planned Development and Political Adaptability in ...
# Found 7 publications on year 1980.
#
# Scraping publications for year: 1979
#   - OP87: A Technique to Study the Effect of TV Violence on ...
#   - OP86: The Feasibility of Contributory Social Security Sc...
#   - OP85: Community Programme Evaluation: A Study of the Dem...
#   - OP84: Commune Education and Rural Development in China...
#   - OP83: Mass Mobilization for Development: Water Conservan...
#   - OP82: Controlling Fertility in China: The Case of Some K...
#   - OP81: Development and the Resuscitation of Rural Leaders...
#   - OP80: High-density Effects in Urban Hong Kong: What Do W...
# Found 8 publications on year 1979.
#
# Scraping publications for year: 1978
#   - OP79: Bureaucratic Corruption in Nineteenth-century Chin...
#   - OP78: From Traditional Familism to Utilitarianistic Fami...
#   - OP77: Dimensions Used in Perceiving Peers: Cross-cultura...
#   - OP76: Neighbourhood Associations in a New Town: The Mutu...
#   - OP75: Life Satisfaction in Crowded Urban Environment...
#   - OP74: Utilitarianistic Familism: The Basis of Political ...
#   - OP73: The Socially Malnourished Children: An Anatomy of ...
#   - OP72: Public Housing Development and Population Movement...
#   - OP71: Material and Non-material Considerations in the Li...
#   - OP70: Family Planning, Fertility Decline, and Family Siz...
#   - OP69: Face Saving in Chinese Culture: A Discussion and E...
#   - OP68: Government Funding of Voluntary Social Services...
# Found 12 publications on year 1978.
#
# Scraping publications for year: 1977
#   - OP67: Managerial Attitudes toward Employees: Traditional...
#   - OP66: Family Structure and Processes in a New Industrial...
#   - OP65: The Development of New Towns in Hong Kong...
#   - OP64: Conflict Behavior and the Escalation of Crisis dur...
#   - OP63: Shame as an Incomplete Conception of Chinese Cultu...
#   - OP62: Housing Policy and Internal Movement of Population...
# Found 6 publications on year 1977.
#
# Scraping publications for year: 1976
#   - OP61: Differentiation of the Confucian Elite and Moderni...
#   - OP60: The Fading of Earthbound Compulsion in a Hong Kong...
#   - OP59: Sex and Social Class Differences in Mental Illness...
#   - OP58: The Family and Family Planning in Kwun Tong: An Ov...
#   - OP57: Patterns of Urban Differentiation in Hong Kong: A ...
# Found 5 publications on year 1976.
#
# Scraping publications for year: 1975
#   - OP56: A Chinese Village in Transition: Some Preliminary ...
#   - OP55: Adolescent Aggression in Hong Kong...
#   - OP54: The Impact of Industrialization on Fertility in Ho...
#   - OP53: The Learning of Population-related Norms: Some Pro...
#   - OP52: The Chinese Touch in Small Industrial Organization...
#   - OP51: Social Causes of Violent Crimes among Young Offend...
#   - OP50: Implications of Concentrated Utilization of Local ...
#   - OP49: Growth and Limitations of Social Science Research ...
#   - OP48: Access to Educational Opportunity: The Case of Kwu...
# Found 9 publications on year 1975.
#
# Scraping publications for year: 1974
#   - OP47: Social Environmental Bases of Fertility Motivation...
#   - OP46: A Chinese Spirit-medium Temple in Kwun Tong: A Pre...
#   - OP45: Industrialization and Family Structure in Hong Kon...
#   - OP44: The Stratification between Modern and Traditional ...
#   - OP43: The Role of Small Factory in Economic Development:...
#   - OP42: Problems of Integrating Chinese and Western Health...
#   - OP41: The Small Factories in Kwun Tong: Problems and Str...
#   - OP40: A Study of Neighborly Interaction in Public Housin...
#   - OP39: The Hostel Need of the Students of The Chinese Uni...
#   - OP38: Non-professional Social Research in Communist Chin...
#   - OP37: Street Trading in Hong Kong: Part III ― An Examina...
#   - OP36: Street Trading in Hong Kong: Part II ― Spatial Eco...
#   - OP35: Street Trading in Hong Kong: Part I ― Population, ...
#   - OP34: Market and Street Trading: A Conceptual Framework...
#   - OP33: Methodological Problems in Data Collection and Que...
# Found 15 publications on year 1974.
#
# Scraping publications for year: 1973
#   - OP32: The Impact of Industrialization on Fertility in Ho...
#   - OP31: On the Conceptualization of Job Satisfaction...
#   - OP30: The Rise and Growth of Kwun Tong: A Study of Plann...
#   - OP29: A Study of the Role of Religious Organizations in ...
#   - OP28: Social Mobility as a Source of Psychic Stress...
#   - OP27: Hawkers and Their Relocation in Hong Kong: Data Bo...
#   - OP26: The Organization and Management of Factories in Kw...
#   - OP25: The Administrative Absorption of Politics in Hong ...
# Found 8 publications on year 1973.
#
# Scraping publications for year: 1972
#   - OP24: Hawkers and Their Relocation in Hong Kong: A Propo...
#   - OP23: Maternal Employment and Family Task-power Differen...
#   - OP22: Hong Kong Managerial Styles: Chinese and Western A...
#   - OP21: Study of Health Systems in Kwun Tong: Preliminary ...
#   - OP20: Study of Health Systems in Kwun Tong: Preliminary ...
#   - OP19: The Spatial Distribution of Organizations in Kwun ...
#   - OP18: The Growth Pattern of Organisations in Kwun Tong...
#   - OP17: The Nature of Kwun Tong as an Industrial Community...
#   - OP16: On the Logic and Strategies of Sociological Inquir...
#   - OP15: Study of Health Systems in Kwun Tong: Preliminary ...
#   - OP14: Spatial Distributions of Modern Western and Tradit...
#   - OP13: Population, Housing and the Availability of Medica...
#   - OP12: Organizational Complexity and Industrial Health Se...
#   - OP11: A Theoretical and Operational Definition of Commun...
#   - OP10: The Study of Higher Non-expatriate Civil Servants ...
#   - OP9: The Political Culture of Kwun Tong: A Chinese Comm...
#   - OP8: Social Welfare Organisations in Kwun Tong: A Proje...
#   - OP7: Action Research in a Social Service Agency Worksho...
#   - OP6: Value Changes during a Period of Modernization: Th...
#   - OP5: Political Orientations in Hong Kong: A Socio-psych...
#   - OP4: Organizational Size, Structural Differentiation an...
#   - OP3: Sampling in the Kwun Tong Industrial Community Res...
# Found 22 publications on year 1972.
#
# Scraping publications for year: 1971
#   - OP2: Socioeconomic Status and Psychiatric Disorder: A P...
#   - OP1: The Education and Professional Training of Seconda...
# Found 2 publications on year 1971.

# %%
def save_to_csv(
    publications: list[dict[str, str]],
    dir_name: str,
    filename: str = "hkiaps_publications.csv",
) -> None:
    """Save publications to CSV file.

    Args:
        publications (List[Dict[str, str]]): List of publication dictionaries
        filename (str): Output CSV filename

    Returns:
        None: Writes data to CSV file

    """
    if not publications:
        print("No publications to save")
        return
    fieldnames = [
        "id",
        "title",
        "metadata",
        "pdf_url",
        "toc_pdf",
        "abstract_url",
        "image_url",
    ]
    filepath = Path(dir_name) / filename
    filepath.parent.mkdir(parents=True, exist_ok=True)
    with Path(filepath).open("w", newline="", encoding="utf-8") as f:
        writer = csv.DictWriter(f, fieldnames=fieldnames, extrasaction="ignore")
        writer.writeheader()
        writer.writerows(publications)
    print(f"\nSaved {len(publications)} publications to {filename}")


save_to_csv(
    publications, dir_name="src-publications", filename="hkiaps_src_publications.csv"
)
print("\n=== Summary ===")
print(f"Total publications: {len(publications)}")
# Out:
# Saved 98 publications to hkiaps_src_publications.csv
#
# === Summary ===
# Total publications: 98
